# %%
import pandas as pd
import matplotlib.pyp25lot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
raw_data_count = recent_grads.shape[0]
print(raw_data_count)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 172

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter',
                  title='Sample Size vs Median');

# %%
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate',
                        kind='scatter',
                        title='Sample Size vs Unemployment Rate');

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median',
                        kind='scatter',
                        title='Full Time vs Median');

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate',
                        kind='scatter',
                        title='Share of Women vs Unemployment Rate');

# %%
ax5 = recent_grads.plot(x='Men', y='Women',
                        kind='scatter',
                        title='Men vs Women');

# %%
ax6 = recent_grads.plot(x='Women', y='Median',
                        kind='scatter',
                        title='Women vs Median');

# %% [markdown]
# ### Some Questions
# * Do students in more popular majors make more money?
# * Do students that majored in subjects that were majority female make more money?
# * Is there any link between the number of full-time employees and median salary?

# %%
# let 'Total' be a substitute for the popularity of the major 
# in order to get an idea of more popular majors earn more
ax7 = recent_grads.plot(x='Total', y='Median',
                        kind='scatter',
                        title='Total vs Median');

# %%
# Does the percent of women in a majority correlate with earnings?
ax8 = recent_grads.plot(x='ShareWomen', y='Median',
                        kind='scatter',
                        title='Share of Women vs Median');

# %%
# Any link between number of full employment and earnings?
ax9 = recent_grads.plot(x='Full_time', y='Median',
                        kind='scatter',
                        title='Full Time vs Median');

# %% [markdown]
# ### Perhaps a few Anwsers...
# The only question we can answer at this time is whether majors with more women earn more, the answer is clearly no. From the graph `ax8` we can see a downward trend as the percent of women in the major increases.
#
# As for the other questions, there may be some relationship but there also appears to be a lot of noise and a lot of clustering around the origin. This makes it difficult to draw conclusions from the data.

# %%
recent_grads['Sample_size'].plot(bins=25, kind='hist');

# %%
recent_grads['Median'].plot(bins=50, kind='hist');

# %%
recent_grads[recent_grads['Median'] == 110000]
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
median_all = recent_grads['Median'].quantile([0.25,0.5,0.75])
q25 = median_all[0.25]
q50 = median_all[0.5]
q75 = median_all[0.75]
print('''The most common median salary range, 
aka the middle 50% range starts at ${} and goes up to ${}. 
The median salary across all majors is ${}.'''
      .format(q25,q75,q50))
# Out:
# The most common median salary range,
# aka the middle 50% range starts at $33000.0 and goes up to $45000.0.
# The median salary across all majors is $36000.0.

# %%
recent_grads['Employed'].plot(bins=30, kind='hist');

# %%
recent_grads['Full_time'].plot(bins=30, kind='hist');

# %%
recent_grads['ShareWomen'].plot(bins=25, kind='hist');

# %%
sw_max = recent_grads['ShareWomen'].max()
sw_min = recent_grads['ShareWomen'].min()

# %%
# Major with the largest percent of women
recent_grads[recent_grads['ShareWomen'] == sw_max]
# Out:
#      Rank  Major_code                      Major    Total     Men    Women  \
# 164   165        2307  EARLY CHILDHOOD EDUCATION  37589.0  1167.0  36422.0
#
#     Major_category  ShareWomen  Sample_size  Employed      ...        \
# 164      Education    0.968954          342     32551      ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 164       7001                 20748        1360           0.040105   28000
#
#      P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 164  21000  35000         23515              7705           2868
#
# [1 rows x 21 columns]

# %%
# Major with the smallest percent of women
recent_grads[recent_grads['ShareWomen'] == sw_min]
# Out:
#     Rank  Major_code                  Major  Total    Men  Women  \
# 73    74        3801  MILITARY TECHNOLOGIES  124.0  124.0    0.0
#
#                          Major_category  ShareWomen  Sample_size  Employed  \
# 73  Industrial Arts & Consumer Services         0.0            4         0
#
#         ...        Part_time  Full_time_year_round  Unemployed  \
# 73      ...                0                   111           0
#
#     Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 73                0.0   40000  40000  40000             0                 0
#
#     Low_wage_jobs
# 73              0
#
# [1 rows x 21 columns]

# %%
wdom_maj = recent_grads[recent_grads['ShareWomen'] >= 0.5].shape[0]
per_wdom_maj = wdom_maj/cleaned_data_count *100
print('The percent of majors with a majority of women is {:.2f}%.'.format(per_wdom_maj))
# Out:
# The percent of majors with a majority of women is 55.81%

# %%
recent_grads['Unemployment_rate'].plot(bins=25, kind='hist');

# %%
unemprt_max = recent_grads['Unemployment_rate'].max()
unemprt_min = recent_grads['Unemployment_rate'].min()

# %%
recent_grads[recent_grads['Unemployment_rate'] == unemprt_max]
# Out:
#    Rank  Major_code                Major   Total     Men  Women  \
# 5     6        2418  NUCLEAR ENGINEERING  2573.0  2200.0  373.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 5    Engineering    0.144967           17      1857      ...              264
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 5                  1449         400           0.177226   65000  50000  102000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 5          1142               657            244
#
# [1 rows x 21 columns]

# %%
recent_grads[recent_grads['Unemployment_rate'] == unemprt_min]
# Out:
#      Rank  Major_code                                       Major   Total  \
# 52     53        4005            MATHEMATICS AND COMPUTER SCIENCE   609.0
# 73     74        3801                       MILITARY TECHNOLOGIES   124.0
# 83     84        3602                                      BOTANY  1329.0
# 112   113        1106                                SOIL SCIENCE   685.0
# 120   121        2301  EDUCATIONAL ADMINISTRATION AND SUPERVISION   804.0
#
#        Men  Women                       Major_category  ShareWomen  \
# 52   500.0  109.0              Computers & Mathematics    0.178982
# 73   124.0    0.0  Industrial Arts & Consumer Services    0.000000
# 83   626.0  703.0               Biology & Life Science    0.528969
# 112  476.0  209.0      Agriculture & Natural Resources    0.305109
# 120  280.0  524.0                            Education    0.651741
#
#      Sample_size  Employed      ...        Part_time  Full_time_year_round  \
# ...

# %%
recent_grads['Men'].plot(bins=50, range=(0,400000), kind='hist');

# %%
recent_grads['Women'].plot(bins=50, range=(0,400000), kind='hist');

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10));

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10));

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False);

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend=False);

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False);

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False);
